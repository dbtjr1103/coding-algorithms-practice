# %% [markdown]
# <a href="https://colab.research.google.com/github/dbtjr1103/Basic_practice/blob/main/%EC%BD%94%ED%85%8C_H_Index_20230326.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
citations = [3, 0, 6, 1, 5]

# %%
citations.sort(reverse=True)

# %%
citations
# Out:
# [6, 5, 3, 1, 0]

# %%
answer = 1
for i in range(len(citations)):
    if citations[i] < i+1:
        answer += 1
print(answer)
# Out:
# 3

# %%
answer = 0
for i in range(len(citations)):
    if citations[i] < i+1:
        answer += 1
print(answer)
# Out:
# 2

# %%
# 틀림
def solution(citations):
    answer = 1
    for i in range(len(citations)):
        if citations[i] < i+1:
           answer += 1
    return answer
# Out:
# 3
# [1, 2]

# %%
def solution(citations):
    citations.sort(reverse=True)
    for i in range(len(citations)):
        if citations[i] < i+1:
           return i
    return len(citations)

# %%
solution([3, 0, 6, 1, 5])
# Out:
# 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)
