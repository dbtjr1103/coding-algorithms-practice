# %% [markdown]
# <a href="https://colab.research.google.com/github/dbtjr1103/Basic_practice/blob/main/%EC%BD%94%ED%85%8C_%EC%98%81%EC%96%B4%EB%81%9D%EB%A7%90%EC%9E%87%EA%B8%B0_20230305.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def solution(n, words):
    tmp = []
    for i in range(1,len(words)):
        if words[i] in tmp:
            return [i%n+1, i//n+1]
            break   
        elif words[i-1][-1] != words[i][0]:
            tmp.append(words[i-1])
            print(words[i])
            return [i%n+1, i//n+1]
            break
        else:
            tmp.append(words[i-1])
            print(tmp)
    return [0,0]

# %%
n = 3
words = ["tank", "kick", "know", "wheel", "land", "dream", "mother", "robot", "tank"]

solution(n,words)
# Out:
# ['tank']
# ['tank', 'kick']
# ['tank', 'kick', 'know']
# ['tank', 'kick', 'know', 'wheel']
# ['tank', 'kick', 'know', 'wheel', 'land']
# ['tank', 'kick', 'know', 'wheel', 'land', 'dream']
# ['tank', 'kick', 'know', 'wheel', 'land', 'dream', 'mother']
# [3, 3]

# %%
#  깔끔한 풀이 
def solution(n, words):
    for p in range(1, len(words)):
        if words[p][0] != words[p-1][-1] or words[p] in words[:p]: return [(p%n)+1, (p//n)+1]
    else:
        return [0,0]
