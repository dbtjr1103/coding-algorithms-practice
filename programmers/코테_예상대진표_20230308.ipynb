# %% [markdown]
# <a href="https://colab.research.google.com/github/dbtjr1103/Basic_practice/blob/main/%EC%BD%94%ED%85%8C_%EC%98%88%EC%83%81%EB%8C%80%EC%A7%84%ED%91%9C_20230308.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def solution(n,a,b):
    answer = 0
    H = int(n/2)
    
    if a <= H and b > H :
        return bin(H).rfind('1')+1
    else:
        H/2

# %%
solution(8, 4, 7).rfind('1')+1
# Out:
# 3

# %%
def solution(n, a, b):
    answer = 0
    
    while a != b :
        answer += 1
        a, b = (a+1)//2, (b+1)//2
    return answer

# %%
solution(8, 4, 7)
# Out:
# 3
