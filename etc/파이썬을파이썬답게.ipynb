# %% [markdown]
# <a href="https://colab.research.google.com/github/dbtjr1103/Basic_practice/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%9D%84%ED%8C%8C%EC%9D%B4%EC%8D%AC%EB%8B%B5%EA%B2%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 프로그래머스 연습
#
# ## 프로그래밍 강의
#
# ### 파이썬을 파이썬답게
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 파트 1. Python 꿀팁

# %%
def solution(mylist):
    answer = []
    for i in mylist:
        answer.append(len(i))
    return answer

# %% [markdown]
# 와.. 기가막히게 똑같이 짰음...
# 동영상에서는 아래처럼 짜야한다고 설명해줌.

# %%
def solution(mylist):
    return list(map(len, mylist))

# %% [markdown]
# [Python 꿀팁 강의 제보]
# glossary - iterable 용어는 이렇게 번역하는 편이 좋을 것 같습니다.
#
# iterable: 자신의 멤버를 한 번에 리턴할 수 있는 객체입니다. list, str, tuple, dict 등이 여기에 속합니다.
# 출처: https://docs.python.org/3/glossary.html#term-iterable,
#
# 저는 Demi이고, 제 레퍼런스 url은 다음과 같습니다. https://github.com/DemiHwang

# %% [markdown]
# iterable: 자신의 멤버를 한 번에 하나씩 리턴할 수 있는 객체입니다. list, str, tuple, dict 등이 여기에 속합니다.
#
# sequence: int 타입 인덱스를 통해, 원소에 접근할 수 있는 iterable 입니다. iterable의 하위 카테고리라고 생각하시면 됩니다. list, str,
# tuple이 여기 속합니다. ( dictionary는 다양한 타입을 통해 원소에 접근할 수 있기 때문에 sequence에 속하지 않습니다.
#
# unpacking: 적절한 번역을 찾고 있습니다.

# %% [markdown]
# ## 파트 2. 정수 다루기

# %%
# 몫과 나머지
a, b = map(int, input().strip().split(' '))
print(a//b, a%b)
# Out:
# 5 3
# 1 2

# %%
# 몫과 나머지 divmod와 unpacking 이용 
a,b = 7,5
print(*divmod(a,b))
# Out:
# 1 2

# %% [markdown]
# 무조건 divmod가 좋은것은 아님, 가독성이나 팀의 코드 스타일에 따라 사용
#
# 작은 숫자를 다룰때는 더 느림

# %%
# n진법으로 표기된 string을 10진법 숫자로 변환하기
num, base = map(int, input().strip().split(' '))
num = str(num)
answer = int(num,base)

print(answer)
# Out:
# 12 3
# 5

# %% [markdown]
# ## 파트 3. Str 다루기

# %% [markdown]
# ### 문자열 정렬하기 - ljust, center, rjust

# %%
# 문자열 정렬하기
s, n = input().strip().split(' ')
n = int(n)

print(s.ljust(n))
print(s.center(n))
print(s.rjust(n))
# Out:
# abc 7
# abc
#   abc
#     abc

# %% [markdown]
# ### 알파벳 출력하기- string 모듈

# %%
# 입력으로 0이 주어지면 영문 소문자 알파벳을, 입력으로 1이 주어지면 영문 대문자 알파벳을 사전 순으로 출력하는 코드를 짜세요.
tmp = int(input().strip())
if tmp:
    print('ABCDEFGHIJKLMNOPQRSTUVWXYZ')
else:
    print('abcdefghijklmnopqrstuvwxyz')
# Out:
# 0
# abcdefghijklmnopqrstuvwxyz

# %%
import string 

string.ascii_lowercase # 소문자 abcdefghijklmnopqrstuvwxyz
string.ascii_uppercase # 대문자 ABCDEFGHIJKLMNOPQRSTUVWXYZ
string.ascii_letters # 대소문자 모두 abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
string.digits # 숫자 0123456789
# Out:
# '0123456789'

# %% [markdown]
# ## 파트 4. Iterable 다루기

# %% [markdown]
# ### 원본을 유지한채, 정렬된 리스트 구하기 - sorted

# %%
list1 = [3, 2, 5, 1]
list2 = [i for i in list1] # 또는 copy.deepcopy를 사용
list2.sort()
list2
# Out:
# [1, 2, 3, 5]

# %%
list1 = [3, 2, 5, 1]
list2 = sorted(list1)
print(list1, list2)
# Out:
# [3, 2, 5, 1] [1, 2, 3, 5]

# %% [markdown]
# ### 2차원 리스트 뒤집기 - zip

# %%
mylist = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
new_list = [[], [], []]

for i in range(len(mylist)):
    for j in range(len(mylist[i])):
        new_list[i].append(mylist[j][i])
new_list
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %%
mylist = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
new_list = list(map(list, zip(*mylist)))
new_list
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %%
mylist = [1, 2, 3]
new_list = [40, 50, 60]
for i in zip(mylist, new_list):
    print(i)
# Out:
# (1, 40)
# (2, 50)
# (3, 60)

# %%
# 사용 예 #1 - 여러 개의 Iterable 동시에 순회할 때 사용
list1 = [1, 2, 3, 4]
list2 = [100, 120, 30, 300]
list3 = [392, 2, 33, 1]
answer = []
for number1, number2, number3 in zip(list1, list2, list3):
   print(number1 + number2 + number3)
# Out:
# 493
# 124
# 66
# 305

# %%
# 사용 예 #2 - Key 리스트와 Value 리스트로 딕셔너리 생성하기
animals = ['cat', 'dog', 'lion']
sounds = ['meow', 'woof', 'roar']
answer = dict(zip(animals, sounds))
answer
# Out:
# {'cat': 'meow', 'dog': 'woof', 'lion': 'roar'}

# %% [markdown]
# ### i번째 원소와 i+1번째 원소 - zip

# %%
def solution(mylist):
    answer = []
    mylist2 = mylist[1:]
    for i,j in zip(mylist, mylist2):
        answer.append(abs(i-j))
    return answer

# %% [markdown]
# ### 모든 멤버의 type 변환하기 - map

# %%
def solution(mylist):
    return list(map(int, mylist))

# %%
# 응용하기
def solution(mylist):
    answer = list(map(len ,mylist))
    return answer

solution([[1], [2]])
# Out:
# [1, 1]

# %% [markdown]
# ## 파트 5. Sequence Types 다루기

# %% [markdown]
# ### sequence 멤버를 하나로 이어붙이기 - join

# %%
def solution(mylist):
    return ''.join(mylist)
solution(['1', '100', '33'] )
# Out:
# '110033'

# %% [markdown]
# ### 삼각형 별찍기 - sequence type의 * 연산

# %%
n = int(input().strip())
for i in range(1,n+1):
    print('*'*i)
# Out:
# 3
# *
# **
# ***

# %% [markdown]
# ## 파트 6. ltertools / Collections 모듈

# %% [markdown]
# ### 곱집합 구하기 - product

# %%
iterable1 = 'ABCD'
iterable2 = 'xy'
# iterable3 = '1234'

for value1 in iterable1:
    for value2 in iterable2:
        print(value1, value2)
        # for value3 in iterable3:
            # print(value1, value2, value3)
# Out:
# A x
# A y
# B x
# B y
# C x
# C y
# D x
# D y

# %%
import itertools

iterable1 = 'ABCD'
iterable2 = 'xy'
print(list(itertools.product(iterable1, iterable2)))
# Out:
# [('A', 'x'), ('A', 'y'), ('B', 'x'), ('B', 'y'), ('C', 'x'), ('C', 'y'), ('D', 'x'), ('D', 'y')]

# %% [markdown]
# ### 2차원 리스트를 1차원 리스트로 만들기 - from_iterable

# %%
my_list = [[1, 2], [3, 4], [5, 6]]
answer = []
for element in my_list:
    answer += element
answer
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 방법1 - sum
my_list = [[1, 2], [3, 4], [5, 6]]
sum(my_list, [])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 방법2 - itertools.chain
my_list = [[1, 2], [3, 4], [5, 6]]
list(itertools.chain.from_iterable(my_list))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 방법2 - itertools와 unpacking
my_list = [[1, 2], [3, 4], [5, 6]]
list(itertools.chain(*my_list))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 방법 4 - list comprehension 이용
[element for array in my_list for element in array]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 방법 5 - reduce 함수 이용 1
# 여러 개의 데이터를 대상으로 주로 누적 집계를 내기 위해서 사용합니다.
from functools import reduce
list(reduce(lambda x, y: x+y, my_list))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 방법 6 - reduce, operator.add 함수 이용
# operator.add 함수는 + 연산자와 동일한 기능을 수행한다.
from functools import reduce
import operator
list(reduce(operator.add, my_list))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 각 원소의 길이가 동일한 경우만 제한적으로 사용 
# 방법 7 - numpy 라이브러리의 flatten 이용
import numpy as np
print(np.array(my_list))
print(np.array(my_list).flatten())
print(np.array(my_list).flatten().tolist())
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# [1 2 3 4 5 6]
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### 순열과 조합 - combinations, permutations

# %%
# 문제
import itertools
def solution(mylist):
    return sorted(list(itertools.permutations(mylist)))
# sort안해주면 틀렸다고나옴

# %%
# 순열
import itertools

pool = ['A', 'B', 'C']
print(list(map(''.join, itertools.permutations(pool))))
print(list(map(''.join, itertools.permutations(pool,2))))
# Out:
# ['ABC', 'ACB', 'BAC', 'BCA', 'CAB', 'CBA']
# ['AB', 'AC', 'BA', 'BC', 'CA', 'CB']

# %%
# 조합
import itertools

pool = ['A', 'B', 'C']
print(list(map(''.join, itertools.combinations(pool,1))))
print(list(map(''.join, itertools.combinations(pool,2))))
print(list(map(''.join, itertools.combinations(pool,3))))
print(list(map(''.join, itertools.combinations(pool,4))))
# Out:
# ['A', 'B', 'C']
# ['AB', 'AC', 'BC']
# ['ABC']
# []

# %% [markdown]
# ### 가장 많이 등장하는 알파벳 찾기- Counter

# %%
import collections

my_str = input().strip()
tmp = collections.Counter(my_str)
mc = tmp.most_common()[0][1]
answer = ''
for i,j in tmp.items():
    if j == mc:
        answer += i
print(''.join(sorted(answer)))
# Out:
# 'ab'

# %%
# Counter
import collections
my_list = [1, 2, 3, 4, 5, 6, 7, 8, 7, 9, 1, 2, 3, 3, 5, 2, 6, 8, 9, 0, 1, 1, 4, 7, 0]
answer = collections.Counter(my_list)
answer
# Out:
# Counter({1: 4, 2: 3, 3: 3, 4: 2, 5: 2, 6: 2, 7: 3, 8: 2, 9: 2, 0: 2})

# %% [markdown]
# ## 파트 7. 기타

# %% [markdown]
# ### for문과 if문을 한번에 - List comprehension(리스트표현식) 의 if문

# %%
def solution(mylist):
    answer = []
    for i in mylist:
        if i % 2 == 0:
            answer.append(i**2)
    return answer

# %%
# list comprehension으로 작성시
def solution(mylist):
    answer = [i**2 for i in mylist if i % 2 == 0]
    return answer

# %% [markdown]
# ### flag OR for-else 사용하기

# %%
# 제곱수도 모르는데.. math.sqrt()
import math
math.sqrt(36)
# Out:
# 6.0

# %%
import math

if __name__ == '__main__':
    numbers = [int(input()) for _ in range(5)]
    multiplied = 1
    for number in numbers:
        multiplied *= number
        if math.sqrt(multiplied) == int(math.sqrt(multiplied)):
            print('found')
            break
    else:
        print('not found')
# Out:
# 3
# 2
# 5
# 1
# 2
# not found

# %% [markdown]
# ### 두 변수의 값 바꾸기 - swap

# %%
a = 3
b = 'abc'

a,b = b,a
print(a,b)
# Out:
# abc 3

# %% [markdown]
# ### 이진 탐색하기 - binary search - bisect

# %%
import bisect
mylist = [1, 2, 3, 7, 9, 11, 33]
print(bisect.bisect(mylist, 11))
# Out:
# 6

# %% [markdown]
# ### 클래스 인스턴스 출력하기 - class의 자동 string casting   : __str__

# %%
class Coord(object):
    def __init__ (self, x, y):
        self.x, self.y = x, y
    def __str__ (self):
        return '({}, {})'.format(self.x, self.y)

print(Coord(1,2))
# Out:
# (1, 2)

# %% [markdown]
# ### 가장 큰 수, inf

# %%
# inf는 어떤 숫자와 비교해도 무조건 크다고 판정
min_val = float('inf')
min_val > 10000000000000000000
# Out:
# True

# %%
max_val = float('-inf')
max_val < 100
# Out:
# True

# %% [markdown]
# ### 파일 입출력 간단하게 하기

# %%
# 기존 방법
f = open('myfile.txt', 'r')
while True:
    line = f.readline()
    if not line: 
        break
    raw = line.split()
    print(raw)
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-131-e0cfe91856d4> in <module>
#       1 # 기존 방법
# ----> 2 f = open('myfile.txt', 'r')
#       3 while True:
#       4     line = f.readline()
#       5     if not line:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myfile.txt'

# %%
# 파이썬의 with - as 구문을 이용하면 코드를 더 간결하게 짤 수 있습니다. 코드를 아래와 같이 쓰면 다음과 같은 장점이 있습니다.
with open('myfile.txt') as file:
    for line in file.readlines():
        print(line.strip().split('\t'))

# %% [markdown]
# ![image.png](data:image/png;base64,...)
